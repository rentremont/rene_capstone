# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
disneylist = pd.read_csv('data/mylist_lmpssa.csv')
disneylist
# Out:
#      Unnamed: 0                                         Release  category  \
# 0             0      Star Wars: Episode VII - The Force Awakens  starwars
# 1             1                               Avengers: Endgame    marvel
# 2             2                                   Black Panther    marvel
# 3             3                          Avengers: Infinity War    marvel
# 4             4                                    The Avengers    marvel
# ..          ...                                             ...       ...
# 636         647              Star Wars: Episode IV - A New Hope  starwars
# 637         648    Star Wars: Episode II - Attack of the Clones  starwars
# 638         649      Star Wars: Episode VI - Return of the Jedi  starwars
# 639         650  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640         651                       Star Wars: The Clone Wars  starwars
#
#     To Date/Lifetime Gross in US and Canada Release Date_x Max Theaters_x  \
# ...

# %%
disneylist=disneylist.drop(['Unnamed: 0'], axis=1)
disneylist
# Out:
#                                             Release  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     To Date/Lifetime Gross in US and Canada Release Date_x Max Theaters_x  \
# 0                             $936,662,225       18-Dec-15          4,134
# ...

# %%
disneylist=disneylist.rename(columns={'Release':'title','category':'category', 'To Date/Lifetime Gross in US and Canada': 'lifetime_gross_us_ca','Release Date_x':'release_date','Max Theaters_x':'max_theaters','Days':'total_days','Opening_x':'opening_weekend','Open Th_x':'opening_theaters','Distributor':'distributor'})
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0          $936,662,225     18-Dec-15        4,134        167   $247,966,675
# ...

# %% [markdown]
# disneylist.loc[disneylist['release_date'].dt.year(69)

# %%
disneylist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 641 non-null    object
#  1   category              641 non-null    object
#  2   lifetime_gross_us_ca  641 non-null    object
#  3   release_date          641 non-null    object
#  4   max_theaters          641 non-null    object
#  5   total_days            620 non-null    object
#  6   opening_weekend       640 non-null    object
#  7   opening_theaters      641 non-null    object
#  8   distributor           108 non-null    object
# dtypes: object(9)
# memory usage: 45.2+ KB

# %%
disneylist['release_date'] = pd.to_datetime(disneylist['release_date'], format = '%d-%b-%y')

# %%
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0          $936,662,225    2015-12-18        4,134        167   $247,966,675
# ...

# %%
disneylist.loc[disneylist['release_date'].between("1968-12-31", "1969-12-31")]
# Out:
#             title category lifetime_gross_us_ca release_date max_theaters  \
# 252  The Love Bug     live         $51,264,000    1969-03-13            -
#
#     total_days opening_weekend opening_theaters distributor
# 252          -               -                -         NaN

# %%
disneylist.loc[disneylist['category']=='starwars']
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 5           Star Wars: Episode VIII - The Last Jedi  starwars
# 9                      Rogue One: A Star Wars Story  starwars
# 10    Star Wars: Episode IX - The Rise of Skywalker  starwars
# 65                          Solo: A Star Wars Story  starwars
# 634       Star Wars: Episode I - The Phantom Menace  starwars
# 635    Star Wars: Episode III - Revenge of the Sith  starwars
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0          $936,662,225    2015-12-18        4,134        167   $247,966,675
# ...

# %%
disneylist.loc[disneylist['title']=='The Lion King']
# Out:
#            title           category lifetime_gross_us_ca release_date  \
# 7  The Lion King  live reimaginings        $543,638,043    2019-07-19
# 8  The Lion King           animated        $312,855,561    1994-06-15
#
#   max_theaters total_days opening_weekend opening_theaters  \
# 7        4,802        139   $191,770,759             4,725
# 8        2,624          -     $1,586,753                 2
#
#                            distributor
# 7  Walt Disney Studios Motion Pictures
# 8  Walt Disney Studios Motion Pictures

# %%
avg_ticket_per_year=pd.read_csv('data/avg_ticket_per_year.csv')
avg_ticket_per_year
# Out:
#     year avg_price
# 0   2023   $10.53
# 1   2022   $10.53
# 2   2021   $10.40
# 3   2020    $9.41
# 4   2019    $9.16
# 5   2018    $9.11
# 6   2017    $8.97
# 7   2016    $8.65
# 8   2015    $8.43
# 9   2014    $8.17
# 10  2013    $8.13
# 11  2012    $7.96
# 12  2011    $7.93
# 13  2010    $7.89
# 14  2009    $7.50
# 15  2008    $7.18
# 16  2007    $6.88
# 17  2006    $6.55
# 18  2005    $6.41
# 19  2004    $6.21
# 20  2003    $6.03
# 21  2002    $5.81
# 22  2001    $5.66
# 23  2000    $5.39
# 24  1999    $5.08
# 25  1998    $4.69
# 26  1997    $4.59
# 27  1996    $4.42
# 28  1995    $4.35
# 29  1994    $4.08
# 30  1993    $4.14
# 31  1992    $4.15
# 32  1991    $4.21
# 33  1990    $4.22
# 34  1989    $3.99
# 35  1988    $4.11
# 36  1987    $3.91
# 37  1986    $3.71
# 38  1985    $3.55
# 39  1984    $3.36
# 40  1983    $3.15
# 41  1982    $2.94
# 42  1981    $2.78
# 43  1980    $2.69
# 44  1979    $2.47
# 45  1978    $2.34
# 46  1977    $2.23
# 47  1976    $2.13
# ...

# %%
avg_ticket_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       56 non-null     int64
#  1   avg_price  56 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
import re

# %%
avg_ticket_per_year['avg_price']=avg_ticket_per_year['avg_price'].str[1: ]
avg_ticket_per_year
# Out:
#     year avg_price
# 0   2023    10.53
# 1   2022    10.53
# 2   2021    10.40
# 3   2020     9.41
# 4   2019     9.16
# 5   2018     9.11
# 6   2017     8.97
# 7   2016     8.65
# 8   2015     8.43
# 9   2014     8.17
# 10  2013     8.13
# 11  2012     7.96
# 12  2011     7.93
# 13  2010     7.89
# 14  2009     7.50
# 15  2008     7.18
# 16  2007     6.88
# 17  2006     6.55
# 18  2005     6.41
# 19  2004     6.21
# 20  2003     6.03
# 21  2002     5.81
# 22  2001     5.66
# 23  2000     5.39
# 24  1999     5.08
# 25  1998     4.69
# 26  1997     4.59
# 27  1996     4.42
# 28  1995     4.35
# 29  1994     4.08
# 30  1993     4.14
# 31  1992     4.15
# 32  1991     4.21
# 33  1990     4.22
# 34  1989     3.99
# 35  1988     4.11
# 36  1987     3.91
# 37  1986     3.71
# 38  1985     3.55
# 39  1984     3.36
# 40  1983     3.15
# 41  1982     2.94
# 42  1981     2.78
# 43  1980     2.69
# 44  1979     2.47
# 45  1978     2.34
# 46  1977     2.23
# 47  1976     2.13
# ...

# %%
avg_ticket_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       56 non-null     int64
#  1   avg_price  56 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.0+ KB

# %%
avg_ticket_per_year = avg_ticket_per_year.astype({'avg_price':'float'})
avg_ticket_per_year
# Out:
#     year  avg_price
# 0   2023      10.53
# 1   2022      10.53
# 2   2021      10.40
# 3   2020       9.41
# 4   2019       9.16
# 5   2018       9.11
# 6   2017       8.97
# 7   2016       8.65
# 8   2015       8.43
# 9   2014       8.17
# 10  2013       8.13
# 11  2012       7.96
# 12  2011       7.93
# 13  2010       7.89
# 14  2009       7.50
# 15  2008       7.18
# 16  2007       6.88
# 17  2006       6.55
# 18  2005       6.41
# 19  2004       6.21
# 20  2003       6.03
# 21  2002       5.81
# 22  2001       5.66
# 23  2000       5.39
# 24  1999       5.08
# 25  1998       4.69
# 26  1997       4.59
# 27  1996       4.42
# 28  1995       4.35
# 29  1994       4.08
# 30  1993       4.14
# 31  1992       4.15
# 32  1991       4.21
# 33  1990       4.22
# 34  1989       3.99
# 35  1988       4.11
# 36  1987       3.91
# 37  1986       3.71
# 38  1985       3.55
# 39  1984       3.36
# 40  1983       3.15
# 41  1982       2.94
# 42  1981       2.78
# 43  1980       2.69
# ...

# %%
avg_ticket_per_year['inflation_rate']= (10.53-avg_ticket_per_year['avg_price'])/avg_ticket_per_year['avg_price']

# %%
avg_ticket_per_year
# Out:
#     year  avg_price  inflation_rate
# 0   2023      10.53        0.000000
# 1   2022      10.53        0.000000
# 2   2021      10.40        0.012500
# 3   2020       9.41        0.119022
# 4   2019       9.16        0.149563
# 5   2018       9.11        0.155873
# 6   2017       8.97        0.173913
# 7   2016       8.65        0.217341
# 8   2015       8.43        0.249110
# 9   2014       8.17        0.288862
# 10  2013       8.13        0.295203
# 11  2012       7.96        0.322864
# 12  2011       7.93        0.327869
# 13  2010       7.89        0.334601
# 14  2009       7.50        0.404000
# 15  2008       7.18        0.466574
# 16  2007       6.88        0.530523
# 17  2006       6.55        0.607634
# 18  2005       6.41        0.642746
# 19  2004       6.21        0.695652
# 20  2003       6.03        0.746269
# 21  2002       5.81        0.812392
# 22  2001       5.66        0.860424
# 23  2000       5.39        0.953618
# 24  1999       5.08        1.072835
# ...

# %%
avg_ticket_per_year.describe()
# Out:
#               year  avg_price  inflation_rate
# count    56.000000  56.000000       56.000000
# mean   1994.392857   5.095714        2.778017
# std      18.413116   2.814130        4.997546
# min    1948.000000   0.360000        0.000000
# 25%    1981.750000   2.900000        0.386650
# 50%    1995.500000   4.385000        1.401521
# 75%    2009.250000   7.597500        2.633167
# max    2023.000000  10.530000       28.250000

# %%
avg_ticket_per_year = avg_ticket_per_year.astype({'year':'int'})
avg_ticket_per_year
# Out:
#     year  avg_price  inflation_rate
# 0   2023      10.53        0.000000
# 1   2022      10.53        0.000000
# 2   2021      10.40        0.012500
# 3   2020       9.41        0.119022
# 4   2019       9.16        0.149563
# 5   2018       9.11        0.155873
# 6   2017       8.97        0.173913
# 7   2016       8.65        0.217341
# 8   2015       8.43        0.249110
# 9   2014       8.17        0.288862
# 10  2013       8.13        0.295203
# 11  2012       7.96        0.322864
# 12  2011       7.93        0.327869
# 13  2010       7.89        0.334601
# 14  2009       7.50        0.404000
# 15  2008       7.18        0.466574
# 16  2007       6.88        0.530523
# 17  2006       6.55        0.607634
# 18  2005       6.41        0.642746
# 19  2004       6.21        0.695652
# 20  2003       6.03        0.746269
# 21  2002       5.81        0.812392
# 22  2001       5.66        0.860424
# 23  2000       5.39        0.953618
# 24  1999       5.08        1.072835
# ...

# %%
avg_ticket_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            56 non-null     int32
#  1   avg_price       56 non-null     float64
#  2   inflation_rate  56 non-null     float64
# dtypes: float64(2), int32(1)
# memory usage: 1.2 KB

# %%
avg_ticket_per_year['year_dif']=2023-avg_ticket_per_year['year']
avg_ticket_per_year
# Out:
#     year  avg_price  inflation_rate  year_dif
# 0   2023      10.53        0.000000         0
# 1   2022      10.53        0.000000         1
# 2   2021      10.40        0.012500         2
# 3   2020       9.41        0.119022         3
# 4   2019       9.16        0.149563         4
# 5   2018       9.11        0.155873         5
# 6   2017       8.97        0.173913         6
# 7   2016       8.65        0.217341         7
# 8   2015       8.43        0.249110         8
# 9   2014       8.17        0.288862         9
# 10  2013       8.13        0.295203        10
# 11  2012       7.96        0.322864        11
# 12  2011       7.93        0.327869        12
# 13  2010       7.89        0.334601        13
# 14  2009       7.50        0.404000        14
# 15  2008       7.18        0.466574        15
# 16  2007       6.88        0.530523        16
# 17  2006       6.55        0.607634        17
# 18  2005       6.41        0.642746        18
# ...

# %%
avg_ticket_per_year['future_value']=avg_ticket_per_year['avg_price']*(1+avg_ticket_per_year['inflation_rate'])**(avg_ticket_per_year['year_dif'])

# %%
avg_ticket_per_year
# Out:
#     year  avg_price  inflation_rate  year_dif   future_value
# 0   2023      10.53        0.000000         0   1.053000e+01
# 1   2022      10.53        0.000000         1   1.053000e+01
# 2   2021      10.40        0.012500         2   1.066163e+01
# 3   2020       9.41        0.119022         3   1.318578e+01
# 4   2019       9.16        0.149563         4   1.599658e+01
# 5   2018       9.11        0.155873         5   1.879613e+01
# 6   2017       8.97        0.173913         6   2.347513e+01
# 7   2016       8.65        0.217341         7   3.426904e+01
# 8   2015       8.43        0.249110         8   4.996132e+01
# 9   2014       8.17        0.288862         9   8.018237e+01
# 10  2013       8.13        0.295203        10   1.080112e+02
# 11  2012       7.96        0.322864        11   1.728150e+02
# 12  2011       7.93        0.327869        12   2.383062e+02
# 13  2010       7.89        0.334601        13   3.362364e+02
# ...

# %%
disneylist['year']=disneylist['release_date'].dt.year
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0          $936,662,225    2015-12-18        4,134        167   $247,966,675
# ...

# %%
disneylist2 = pd.merge(disneylist, avg_ticket_per_year, 
                               left_on = 'year', right_on = 'year', 
                               how = 'left')
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0          $936,662,225    2015-12-18        4,134        167   $247,966,675
# ...

# %%
disneylist2['lifetime_gross_us_ca']=disneylist2['lifetime_gross_us_ca'].str[1: ]
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0           936,662,225    2015-12-18        4,134        167   $247,966,675
# ...

# %%
disneylist2['lifetime_gross_us_ca']=disneylist2.astype({'lifetime_gross_us_ca':'float'})
disneylist2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 disneylist2['lifetime_gross_us_ca']=disneylist2.astype({'lifetime_gross_us_ca':'float'})
#       2 disneylist2
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6226, in NDFrame.astype(self, dtype, copy, errors)
#    6224             res_col = col.copy() if copy else col
#    6225         else:
# -> 6226             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6227         results.append(res_col)
#    6229 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    6230     # GH 18099/22869: columnwise conversion to extension dtype
#    6231     # GH 24704: use iloc to handle duplicate column names
#    6232     # TODO(EA2D): special case not needed with 2D EAs
#
# ...

# %%
disneylist2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 0 to 640
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 641 non-null    object
#  1   category              641 non-null    object
#  2   lifetime_gross_us_ca  641 non-null    object
#  3   release_date          641 non-null    datetime64[ns]
#  4   max_theaters          641 non-null    object
#  5   total_days            620 non-null    object
#  6   opening_weekend       640 non-null    object
#  7   opening_theaters      641 non-null    object
#  8   distributor           108 non-null    object
#  9   year                  641 non-null    int64
#  10  avg_price             629 non-null    float64
#  11  inflation_rate        629 non-null    float64
#  12  year_dif              629 non-null    float64
#  13  future_value          629 non-null    float64
# ...

# %%
disneylist2['num_tickets']=disneylist2['lifetime_gross_us_ca']/disneylist2['avg_price']
disneylist2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...

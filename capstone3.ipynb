# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
disneylist = pd.read_csv('data/mylist_lmpssa.csv')
disneylist
# Out:
#      Unnamed: 0                                         Release  category  \
# 0             0      Star Wars: Episode VII - The Force Awakens  starwars
# 1             1                               Avengers: Endgame    marvel
# 2             2                                   Black Panther    marvel
# 3             3                          Avengers: Infinity War    marvel
# 4             4                                    The Avengers    marvel
# ..          ...                                             ...       ...
# 636         647              Star Wars: Episode IV - A New Hope  starwars
# 637         648    Star Wars: Episode II - Attack of the Clones  starwars
# 638         649      Star Wars: Episode VI - Return of the Jedi  starwars
# 639         650  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640         651                       Star Wars: The Clone Wars  starwars
#
#      To Date/Lifetime Gross in US and Canada Release Date_x Max Theaters_x  \
# ...

# %%
disneylist=disneylist.drop(['Unnamed: 0'], axis=1)
disneylist
# Out:
#                                             Release  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      To Date/Lifetime Gross in US and Canada Release Date_x Max Theaters_x  \
# 0                                  936662225      18-Dec-15          4,134
# ...

# %%
disneylist=disneylist.rename(columns={'Release':'title','category':'category', 'To Date/Lifetime Gross in US and Canada': 'lifetime_gross_us_ca','Release Date_x':'release_date','Max Theaters_x':'max_theaters','Days':'total_days','Opening_x':'opening_weekend','Open Th_x':'opening_theaters','Distributor':'distributor'})
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225    18-Dec-15        4,134        167
# 1               858373000    26-Apr-19        4,662        139
# ...

# %%
disneylist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 641 non-null    object
#  1   category              641 non-null    object
#  2   lifetime_gross_us_ca  641 non-null    int64
#  3   release_date          641 non-null    object
#  4   max_theaters          641 non-null    object
#  5   total_days            620 non-null    object
#  6   opening_weekend       640 non-null    object
#  7   opening_theaters      641 non-null    object
#  8   distributor           108 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 45.2+ KB

# %%
disneylist['release_date'] = pd.to_datetime(disneylist['release_date'], format = '%d-%b-%y')

# %%
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist.loc[disneylist['title'] == 'Mary Poppins']
# Out:
#             title category  lifetime_gross_us_ca release_date max_theaters  \
# 230  Mary Poppins     live             102272727   2064-08-29            -
#
#     total_days opening_weekend opening_theaters distributor
# 230          -               -                -         NaN

# %%
disneylist.loc[230, ['release_date']] = ['1964-08-29']

# %%
disneylist.loc[disneylist['title'] == 'The Jungle Book']
# Out:
#               title           category  lifetime_gross_us_ca release_date  \
# 26  The Jungle Book  live reimaginings             364001123   2016-04-15
# 27  The Jungle Book           animated             141843612   2067-10-18
# 28  The Jungle Book  live reimaginings              43229904   1994-12-25
#
#    max_theaters total_days opening_weekend opening_theaters  \
# 26        4,144        167       103261464            4,028
# 27            -          -         5291670                -
# 28        2,012          -         5129959            1,880
#
#                             distributor
# 26  Walt Disney Studios Motion Pictures
# 27  Walt Disney Studios Motion Pictures
# 28  Walt Disney Studios Motion Pictures

# %%
disneylist.loc[27, ['release_date']] = ['1967-10-18']

# %%
disneylist.loc[disneylist['title'] == 'Cinderella']
# Out:
#          title           category  lifetime_gross_us_ca release_date  \
# 70  Cinderella  live reimaginings             201151353   2015-03-13
# 71  Cinderella           animated              93141149   2050-03-04
#
#    max_theaters total_days opening_weekend opening_theaters  \
# 70        3,848        188        67877361            3,845
# 71            -          -         1300000                -
#
#                             distributor
# 70  Walt Disney Studios Motion Pictures
# 71  Walt Disney Studios Motion Pictures

# %%
disneylist.loc[71, ['release_date']] = ['1950-03-04']

# %%
disneylist.loc[disneylist['title'] == 'Snow White and the Seven Dwarfs']
# Out:
#                                title  category  lifetime_gross_us_ca  \
# 200  Snow White and the Seven Dwarfs  animated             184925486
#
#     release_date max_theaters total_days opening_weekend opening_theaters  \
# 200   2037-12-21            -          -         6017914                -
#
#     distributor
# 200         NaN

# %%
disneylist.loc[200, ['release_date']] = ['1937-12-21']

# %%
disneylist.loc[disneylist['title'] == 'Fantasia']
# Out:
#         title  category  lifetime_gross_us_ca release_date max_theaters  \
# 285  Fantasia  animated              76408097   2041-01-29            -
#
#     total_days opening_weekend opening_theaters distributor
# 285          -          980798                -         NaN

# %%
disneylist.loc[200, ['release_date']] = ['1937-12-21']

# %%
disneylist.loc[285, ['release_date']] = ['1941-01-29']

# %%
disneylist.loc[disneylist['title'] == 'Peter Pan']
# Out:
#          title  category  lifetime_gross_us_ca release_date max_theaters  \
# 290  Peter Pan  animated              87404651   2053-02-05            -
#
#     total_days opening_weekend opening_theaters distributor
# 290          -          957256                -         NaN

# %%
disneylist.loc[290, ['release_date']] = ['1953-02-05']

# %%
disneylist.loc[disneylist['title'] == 'Swiss Family Robinson']
# Out:
#                      title category  lifetime_gross_us_ca release_date  \
# 293  Swiss Family Robinson     live              40356000   2060-12-10
#
#     max_theaters total_days opening_weekend opening_theaters distributor
# 293            -          -               -                -         NaN

# %%
disneylist.loc[293, ['release_date']] = ['1960-12-10']

# %%
disneylist.loc[disneylist['title'] == 'Pinocchio']
# Out:
#          title  category  lifetime_gross_us_ca release_date max_theaters  \
# 300  Pinocchio  animated              84254167   2040-02-09            -
#
#     total_days opening_weekend opening_theaters distributor
# 300          -               -                -         NaN

# %%
disneylist.loc[300, ['release_date']] = ['1940-02-09']

# %%
disneylist.loc[disneylist['title'] == 'Sleeping Beauty']
# Out:
#                title  category  lifetime_gross_us_ca release_date  \
# 314  Sleeping Beauty  animated              51600000   2059-01-29
#
#     max_theaters total_days opening_weekend opening_theaters distributor
# 314            -          -               -                -         NaN

# %%
disneylist.loc[314, ['release_date']] = ['1959-01-29']

# %%
disneylist.loc[disneylist['title'] == 'Lady and the Tramp']
# Out:
#                   title  category  lifetime_gross_us_ca release_date  \
# 317  Lady and the Tramp  animated              93602326   2055-06-22
#
#     max_theaters total_days opening_weekend opening_theaters distributor
# 317            -          -               -                -         NaN

# %%
disneylist.loc[317, ['release_date']] = ['1955-06-22']

# %%
disneylist.loc[disneylist['title'] == 'One Hundred and One Dalmatians']
# Out:
#                               title  category  lifetime_gross_us_ca  \
# 473  One Hundred and One Dalmatians  animated             144880014
#
#     release_date max_theaters total_days opening_weekend opening_theaters  \
# 473   2061-01-25            -          -               -                -
#
#     distributor
# 473         NaN

# %%
disneylist.loc[473, ['release_date']] = ['1961-01-25']

# %%
disneylist.loc[disneylist['title'] == 'One Hundred and One Dalmatians']
# Out:
#                               title  category  lifetime_gross_us_ca  \
# 473  One Hundred and One Dalmatians  animated             144880014
#
#     release_date max_theaters total_days opening_weekend opening_theaters  \
# 473   1961-01-25            -          -               -                -
#
#     distributor
# 473         NaN

# %%
adjusted_data=pd.read_csv('data/adjusted.csv')
adjusted_data
# Out:
#      Unnamed: 0  Rank                               Title Adj. Lifetime Gross  \
# 0             0     1                  Gone with the Wind      $1,895,421,694
# 1             1     2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2             2     3                  The Sound of Music      $1,335,086,324
# 3             3     4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4             4     5                             Titanic      $1,270,101,626
# ..          ...   ...                                 ...                 ...
# 995         195   996                     Friday the 13th        $138,476,419
# 996         196   997        Murder on the Orient Express        $138,468,923
# 997         197   998   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 998         198   999                        Mystic River        $138,398,648
# 999         199  1000                         Sea of Love        $138,240,295
#
# ...

# %%
adjusted_data=adjusted_data.drop(['Unnamed: 0'], axis=1)
adjusted_data
# Out:
#      Rank                               Title Adj. Lifetime Gross  \
# 0       1                  Gone with the Wind      $1,895,421,694
# 1       2  Star Wars: Episode IV - A New Hope      $1,668,979,715
# 2       3                  The Sound of Music      $1,335,086,324
# 3       4          E.T. the Extra-Terrestrial      $1,329,174,791
# 4       5                             Titanic      $1,270,101,626
# ..    ...                                 ...                 ...
# 995   996                     Friday the 13th        $138,476,419
# 996   997        Murder on the Orient Express        $138,468,923
# 997   998   Spy Kids 2: Island of Lost Dreams        $138,438,939
# 998   999                        Mystic River        $138,398,648
# 999  1000                         Sea of Love        $138,240,295
#
#     Lifetime Gross  Est. Num Tickets  Year
# 0     $200,882,193         202286200  1939
# 1     $460,998,507         178119500  1977
# ...

# %%
disneylist3 = pd.merge(disneylist, adjusted_data, 
                               left_on = 'title', right_on = 'Title', 
                               how = 'left')
disneylist3
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 647              Star Wars: Episode IV - A New Hope  starwars
# 648    Star Wars: Episode II - Attack of the Clones  starwars
# 649      Star Wars: Episode VI - Return of the Jedi  starwars
# 650  Star Wars: Episode V - The Empire Strikes Back  starwars
# 651                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
avg_ticket_per_year=pd.read_csv('data/avg_ticket_per_year.csv')
avg_ticket_per_year
# Out:
#     year  avg_price  adj_price
# 0   2023      10.53      10.53
# 1   2022      10.53      10.98
# 2   2021      10.40      11.71
# 3   2020       9.41      11.09
# 4   2019       9.16      10.93
# ..   ...        ...        ...
# 82  1941       0.25       5.19
# 83  1940       0.24       5.23
# 84  1939       0.23       5.05
# 85  1938       0.25       5.41
# 86  1937       0.25       5.30
#
# [87 rows x 3 columns]

# %%
avg_ticket_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       87 non-null     int64
#  1   avg_price  87 non-null     float64
#  2   adj_price  87 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 2.2 KB

# %%
avg_ticket_per_year['inflation_rate']= (10.53-avg_ticket_per_year['avg_price'])/avg_ticket_per_year['avg_price']

# %%
avg_ticket_per_year
# Out:
#     year  avg_price  adj_price  inflation_rate
# 0   2023      10.53      10.53        0.000000
# 1   2022      10.53      10.98        0.000000
# 2   2021      10.40      11.71        0.012500
# 3   2020       9.41      11.09        0.119022
# 4   2019       9.16      10.93        0.149563
# ..   ...        ...        ...             ...
# 82  1941       0.25       5.19       41.120000
# 83  1940       0.24       5.23       42.875000
# 84  1939       0.23       5.05       44.782609
# 85  1938       0.25       5.41       41.120000
# 86  1937       0.25       5.30       41.120000
#
# [87 rows x 4 columns]

# %%
avg_ticket_per_year.describe()
# Out:
#               year  avg_price  adj_price  inflation_rate
# count    87.000000  87.000000  87.000000       87.000000
# mean   1980.000000   3.518046   8.979655        9.596884
# std      25.258662   3.112260   2.299259       12.520388
# min    1937.000000   0.230000   4.560000        0.000000
# 25%    1958.500000   0.640000   6.950000        0.836408
# 50%    1980.000000   2.690000   9.820000        2.914498
# 75%    2001.500000   5.735000  10.715000       15.517647
# max    2023.000000  10.530000  12.430000       44.782609

# %% [markdown]
# avg_ticket_per_year = avg_ticket_per_year.astype({'year':'int'})
# avg_ticket_per_year

# %%
avg_ticket_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            87 non-null     int64
#  1   avg_price       87 non-null     float64
#  2   adj_price       87 non-null     float64
#  3   inflation_rate  87 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 2.8 KB

# %%
avg_ticket_per_year['year_dif']=2023-avg_ticket_per_year['year']
avg_ticket_per_year
# Out:
#     year  avg_price  adj_price  inflation_rate  year_dif
# 0   2023      10.53      10.53        0.000000         0
# 1   2022      10.53      10.98        0.000000         1
# 2   2021      10.40      11.71        0.012500         2
# 3   2020       9.41      11.09        0.119022         3
# 4   2019       9.16      10.93        0.149563         4
# ..   ...        ...        ...             ...       ...
# 82  1941       0.25       5.19       41.120000        82
# 83  1940       0.24       5.23       42.875000        83
# 84  1939       0.23       5.05       44.782609        84
# 85  1938       0.25       5.41       41.120000        85
# 86  1937       0.25       5.30       41.120000        86
#
# [87 rows x 5 columns]

# %% [markdown]
# avg_ticket_per_year['future_value']=avg_ticket_per_year['avg_price']*(1+avg_ticket_per_year['inflation_rate'])**(avg_ticket_per_year['year_dif'])

# %%
disneylist['year']=disneylist['release_date'].dt.year
disneylist
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist2 = pd.merge(disneylist, avg_ticket_per_year, 
                               left_on = 'year', right_on = 'year', 
                               how = 'left')
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641 entries, 0 to 640
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 641 non-null    object
#  1   category              641 non-null    object
#  2   lifetime_gross_us_ca  641 non-null    int64
#  3   release_date          641 non-null    datetime64[ns]
#  4   max_theaters          641 non-null    object
#  5   total_days            620 non-null    object
#  6   opening_weekend       640 non-null    object
#  7   opening_theaters      641 non-null    object
#  8   distributor           108 non-null    object
#  9   year                  641 non-null    int64
#  10  avg_price             641 non-null    float64
#  11  adj_price             641 non-null    float64
#  12  inflation_rate        641 non-null    float64
#  13  year_dif              641 non-null    int64
# ...

# %%
disneylist2['num_tickets']=disneylist2['lifetime_gross_us_ca']/disneylist2['avg_price']
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist2['adjusted_total']=disneylist2['num_tickets']*disneylist2['adj_price']
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist2.loc[disneylist2['year'] <= 1982]
# Out:
#                                               title  category  \
# 27                                  The Jungle Book  animated
# 71                                       Cinderella  animated
# 129                                   Freaky Friday      live
# 181                                   Pete's Dragon  animated
# 200                 Snow White and the Seven Dwarfs  animated
# 230                                    Mary Poppins      live
# 252                                    The Love Bug      live
# 285                                        Fantasia  animated
# 290                                       Peter Pan  animated
# 293                           Swiss Family Robinson      live
# 296                           The Fox and the Hound  animated
# 300                                       Pinocchio  animated
# 302                              Herbie Rides Again      live
# 310                         The Apple Dumpling Gang      live
# ...

# %% [markdown]
# ## movies released before 1982 do not have as much data. Most do not have opening weekend totals or number of theaters.

# %% [markdown]
# disneylist2.to_csv()

# %% [markdown]
# import os
# os.makedirs('data', exist_ok=True)
# disneylist2.to_csv('data/disneylist2.csv')

# %%
disneylist2.loc[(disneylist2['category'] == 'starwars') & (disneylist2['release_date'] <= '2012-10-30')]
# Out:
#                                               title  category  \
# 634       Star Wars: Episode I - The Phantom Menace  starwars
# 635    Star Wars: Episode III - Revenge of the Sith  starwars
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 634             474544677   1999-05-19         3126        NaN
# 635             380270577   2005-05-19         3663        NaN
# 636             460998507   1977-05-25         1750        NaN
# 637             310676740   2002-05-16         3161        NaN
# 638             316566101   1983-05-25         1764        NaN
# 639             292753960   1980-05-21         1278        NaN
# ...

# %%
disneylist2.loc[(disneylist2['category'] == 'starwars') & (disneylist2['release_date'] >= '2012-10-30')]
# Out:
#                                             title  category  \
# 0      Star Wars: Episode VII - The Force Awakens  starwars
# 5         Star Wars: Episode VIII - The Last Jedi  starwars
# 9                    Rogue One: A Star Wars Story  starwars
# 10  Star Wars: Episode IX - The Rise of Skywalker  starwars
# 65                        Solo: A Star Wars Story  starwars
#
#     lifetime_gross_us_ca release_date max_theaters total_days opening_weekend  \
# 0              936662225   2015-12-18        4,134        167       247966675
# 5              620181382   2017-12-15        4,232        125       220009584
# 9              532177324   2016-12-16        4,157        139       155081681
# 10             515202542   2019-12-20        4,406          -       177383864
# 65             213767512   2018-05-25        4,381        118        84420489
#
#    opening_theaters                          distributor  year  avg_price  \
# ...

# %%
for ind, row in disneylist2.iterrows():

    if row.category == 'animated':
        disneylist2.loc[ind, 'style'] = 'A'
    elif row.category == 'live':
        disneylist2.loc[ind, 'style'] = 'L'
    elif row.category == 'marvel':
        disneylist2.loc[ind, 'style'] = 'L'
    elif row.category == 'starwars':
        disneylist2.loc[ind, 'style'] = 'L'
    elif row.category == 'spiderman':
        disneylist2.loc[ind, 'style'] = 'L'
    elif row.category == 'pixar':
        disneylist2.loc[ind, 'style'] = 'A' 
    elif row.category == 'live reimaginings':
        disneylist2.loc[ind, 'style'] = 'L'        
    else:
        disneylist2.loc[ind, 'style'] = 'ERROR'
        
disneylist2
# Out:
#                                               title  category  \
# 0        Star Wars: Episode VII - The Force Awakens  starwars
# 1                                 Avengers: Endgame    marvel
# 2                                     Black Panther    marvel
# 3                            Avengers: Infinity War    marvel
# 4                                      The Avengers    marvel
# ..                                              ...       ...
# 636              Star Wars: Episode IV - A New Hope  starwars
# 637    Star Wars: Episode II - Attack of the Clones  starwars
# 638      Star Wars: Episode VI - Return of the Jedi  starwars
# 639  Star Wars: Episode V - The Empire Strikes Back  starwars
# 640                       Star Wars: The Clone Wars  starwars
#
#      lifetime_gross_us_ca release_date max_theaters total_days  \
# 0               936662225   2015-12-18        4,134        167
# 1               858373000   2019-04-26        4,662        139
# ...

# %%
disneylist2.loc[(disneylist2['year'] > 2023)]
# Out:
# Empty DataFrame
# Columns: [title, category, lifetime_gross_us_ca, release_date, max_theaters, total_days, opening_weekend, opening_theaters, distributor, year, avg_price, adj_price, inflation_rate, year_dif, num_tickets, adjusted_total, style]
# Index: []

# %%
disneylist2.loc[(disneylist2['title'] == 'Lady and the Tramp')]
# Out:
#                   title  category  lifetime_gross_us_ca release_date  \
# 317  Lady and the Tramp  animated              93602326   1955-06-22
#
#     max_theaters total_days opening_weekend opening_theaters distributor  \
# 317            -          -               -                -         NaN
#
#      year  avg_price  adj_price  inflation_rate  year_dif   num_tickets  \
# 317  1955       0.45       5.12            22.4        68  2.080052e+08
#
#      adjusted_total style
# 317    1.064986e+09     A

# %% [markdown]
# import os
# os.makedirs('data', exist_ok=True)
# disneylist2.to_csv('data/disneylist2.csv')

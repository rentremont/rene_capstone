# %%
import pandas as pd
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
disneylive = pd.read_csv('data/live.csv')

# %%
disneymarvel = pd.read_csv('data/marvel.csv')

# %%
disneypixar = pd.read_csv('data/pixar.csv')

# %%
disneyspiderman = pd.read_csv('data/spiderman.csv')

# %%
disneystarwars = pd.read_csv('data/starwars.csv')

# %%
disneywdanimation = pd.read_csv('data/wdanimation.csv')

# %%
disneylive
# Out:
#     Unnamed: 0 Rank                              Release Lifetime Gross  \
# 0            0    1                        The Lion King   $543,638,043
# 1            1    2                 Beauty and the Beast   $504,014,165
# 2            2    3                      The Jungle Book   $364,001,123
# 3            3    4                              Aladdin   $355,559,216
# 4            4    5                  Alice in Wonderland   $334,191,110
# 5            5    6                           Maleficent   $241,410,378
# 6            6    7            Oz the Great and Powerful   $234,911,825
# 7            7    8                           Cinderella   $201,151,353
# 8            8    9                       101 Dalmatians   $136,189,294
# 9            9   10                                Dumbo   $114,766,307
# 10          10   11         Maleficent: Mistress of Evil   $113,929,605
# 11          11   12                              Cruella    $86,103,234
# ...

# %%
disneylive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      18 non-null     int64
#  1   Rank            18 non-null     object
#  2   Release         18 non-null     object
#  3   Lifetime Gross  18 non-null     object
#  4   Max Theaters    18 non-null     object
#  5   Opening         18 non-null     object
#  6   Open Th         18 non-null     object
#  7   Release Date    18 non-null     object
#  8   Distributor     18 non-null     object
#  9   Estimated       18 non-null     bool
# dtypes: bool(1), int64(1), object(8)
# memory usage: 1.4+ KB

# %%
disneylive=disneylive.drop(['Unnamed: 0'], axis=1)
disneylive
# Out:
#    Rank                              Release Lifetime Gross Max Theaters  \
# 0     1                        The Lion King   $543,638,043         4802
# 1     2                 Beauty and the Beast   $504,014,165         4210
# 2     3                      The Jungle Book   $364,001,123         4144
# 3     4                              Aladdin   $355,559,216         4476
# 4     5                  Alice in Wonderland   $334,191,110         3739
# 5     6                           Maleficent   $241,410,378         3948
# 6     7            Oz the Great and Powerful   $234,911,825         3912
# 7     8                           Cinderella   $201,151,353         3848
# 8     9                       101 Dalmatians   $136,189,294         2901
# 9    10                                Dumbo   $114,766,307         4259
# 10   11         Maleficent: Mistress of Evil   $113,929,605         3820
# 11   12                              Cruella    $86,103,234         3922
# ...

# %%
disneylive=disneylive.drop(disneylive.index[17:])
disneylive
# Out:
#    Rank                              Release Lifetime Gross Max Theaters  \
# 0     1                        The Lion King   $543,638,043         4802
# 1     2                 Beauty and the Beast   $504,014,165         4210
# 2     3                      The Jungle Book   $364,001,123         4144
# 3     4                              Aladdin   $355,559,216         4476
# 4     5                  Alice in Wonderland   $334,191,110         3739
# 5     6                           Maleficent   $241,410,378         3948
# 6     7            Oz the Great and Powerful   $234,911,825         3912
# 7     8                           Cinderella   $201,151,353         3848
# 8     9                       101 Dalmatians   $136,189,294         2901
# 9    10                                Dumbo   $114,766,307         4259
# 10   11         Maleficent: Mistress of Evil   $113,929,605         3820
# 11   12                              Cruella    $86,103,234         3922
# ...

# %%
disneymarvel
# Out:
#     Unnamed: 0 Rank                                      Release  \
# 0            0    1                            Avengers: Endgame
# 1            1    2                      Spider-Man: No Way Home
# 2            2    3                                Black Panther
# 3            3    4                       Avengers: Infinity War
# 4            4    5                                 The Avengers
# 5            5    6                      Avengers: Age of Ultron
# 6            6    7               Black Panther: Wakanda Forever
# 7            7    8                               Captain Marvel
# 8            8    9  Doctor Strange in the Multiverse of Madness
# 9            9   10                                   Iron Man 3
# 10          10   11                   Captain America: Civil War
# 11          11   12                    Spider-Man: Far from Home
# 12          12   13               Guardians of the Galaxy Vol. 2
# ...

# %%
disneymarvel=disneymarvel.drop(['Unnamed: 0'], axis=1)
disneymarvel
# Out:
#    Rank                                      Release Lifetime Gross  \
# 0     1                            Avengers: Endgame   $858,373,000
# 1     2                      Spider-Man: No Way Home   $804,793,477
# 2     3                                Black Panther   $700,059,566
# 3     4                       Avengers: Infinity War   $678,815,482
# 4     5                                 The Avengers   $623,357,910
# 5     6                      Avengers: Age of Ultron   $459,005,868
# 6     7               Black Panther: Wakanda Forever   $453,829,060
# 7     8                               Captain Marvel   $426,829,839
# 8     9  Doctor Strange in the Multiverse of Madness   $411,331,607
# 9    10                                   Iron Man 3   $409,013,994
# 10   11                   Captain America: Civil War   $408,084,349
# 11   12                    Spider-Man: Far from Home   $390,532,085
# 12   13               Guardians of the Galaxy Vol. 2   $389,813,101
# ...

# %%
disneymarvel=disneymarvel.drop(disneymarvel.index[32:])

# %%
disneymarvel
# Out:
#    Rank                                      Release Lifetime Gross  \
# 0     1                            Avengers: Endgame   $858,373,000
# 1     2                      Spider-Man: No Way Home   $804,793,477
# 2     3                                Black Panther   $700,059,566
# 3     4                       Avengers: Infinity War   $678,815,482
# 4     5                                 The Avengers   $623,357,910
# 5     6                      Avengers: Age of Ultron   $459,005,868
# 6     7               Black Panther: Wakanda Forever   $453,829,060
# 7     8                               Captain Marvel   $426,829,839
# 8     9  Doctor Strange in the Multiverse of Madness   $411,331,607
# 9    10                                   Iron Man 3   $409,013,994
# 10   11                   Captain America: Civil War   $408,084,349
# 11   12                    Spider-Man: Far from Home   $390,532,085
# 12   13               Guardians of the Galaxy Vol. 2   $389,813,101
# ...

# %%
disneylive['category'] = 'live reimaginings'

# %%
disneymarvel['category'] = 'marvel'

# %%
livemarvel = pd.concat([disneylive, disneymarvel])
livemarvel
# Out:
#    Rank                                      Release Lifetime Gross  \
# 0     1                                The Lion King   $543,638,043
# 1     2                         Beauty and the Beast   $504,014,165
# 2     3                              The Jungle Book   $364,001,123
# 3     4                                      Aladdin   $355,559,216
# 4     5                          Alice in Wonderland   $334,191,110
# 5     6                                   Maleficent   $241,410,378
# 6     7                    Oz the Great and Powerful   $234,911,825
# 7     8                                   Cinderella   $201,151,353
# 8     9                               101 Dalmatians   $136,189,294
# 9    10                                        Dumbo   $114,766,307
# 10   11                 Maleficent: Mistress of Evil   $113,929,605
# 11   12                                      Cruella    $86,103,234
# 12   13              Alice Through the Looking Glass    $77,041,381
# ...

# %%
livemarvel=livemarvel.reset_index()

# %%
livemarvel=livemarvel.drop(['index'], axis=1)
livemarvel
# Out:
#    Rank                                      Release Lifetime Gross  \
# 0     1                                The Lion King   $543,638,043
# 1     2                         Beauty and the Beast   $504,014,165
# 2     3                              The Jungle Book   $364,001,123
# 3     4                                      Aladdin   $355,559,216
# 4     5                          Alice in Wonderland   $334,191,110
# 5     6                                   Maleficent   $241,410,378
# 6     7                    Oz the Great and Powerful   $234,911,825
# 7     8                                   Cinderella   $201,151,353
# 8     9                               101 Dalmatians   $136,189,294
# 9    10                                        Dumbo   $114,766,307
# 10   11                 Maleficent: Mistress of Evil   $113,929,605
# 11   12                                      Cruella    $86,103,234
# 12   13              Alice Through the Looking Glass    $77,041,381
# ...

# %%
disneypixar
# Out:
#     Unnamed: 0  Rank                        Release Lifetime Gross  \
# 0            0     1                  Incredibles 2   $608,581,744
# 1            1     2                   Finding Dory   $486,295,561
# 2            2     3                    Toy Story 4   $434,038,008
# 3            3     4                    Toy Story 3   $415,004,880
# 4            4     5                     Inside Out   $356,461,711
# 5            5     6                   Finding Nemo   $339,714,978
# 6            6     7                             Up   $293,004,164
# 7            7     8            Monsters University   $268,492,764
# 8            8     9                The Incredibles   $261,441,092
# 9            9    10                 Monsters, Inc.   $255,873,250
# 10          10    11                    Toy Story 2   $245,852,179
# 11          11    12                           Cars   $244,082,982
# 12          12    13                          Brave   $237,283,207
# ...

# %%
disneypixar=disneypixar.drop(['Unnamed: 0'], axis=1)
disneypixar
# Out:
#     Rank                        Release Lifetime Gross  Max Theaters  \
# 0      1                  Incredibles 2   $608,581,744          4410
# 1      2                   Finding Dory   $486,295,561          4305
# 2      3                    Toy Story 4   $434,038,008          4575
# 3      4                    Toy Story 3   $415,004,880          4028
# 4      5                     Inside Out   $356,461,711          4158
# 5      6                   Finding Nemo   $339,714,978          3425
# 6      7                             Up   $293,004,164          3886
# 7      8            Monsters University   $268,492,764          4004
# 8      9                The Incredibles   $261,441,092          3933
# 9     10                 Monsters, Inc.   $255,873,250          3649
# 10    11                    Toy Story 2   $245,852,179          3257
# 11    12                           Cars   $244,082,982          3988
# 12    13                          Brave   $237,283,207          4164
# ...

# %%
disneypixar=disneypixar.drop(disneypixar.index[22:])
disneypixar
# Out:
#     Rank              Release Lifetime Gross  Max Theaters       Opening  \
# 0      1        Incredibles 2   $608,581,744          4410  $182,687,905
# 1      2         Finding Dory   $486,295,561          4305  $135,060,273
# 2      3          Toy Story 4   $434,038,008          4575  $120,908,065
# 3      4          Toy Story 3   $415,004,880          4028  $110,307,189
# 4      5           Inside Out   $356,461,711          4158   $90,440,272
# 5      6         Finding Nemo   $339,714,978          3425   $70,251,710
# 6      7                   Up   $293,004,164          3886   $68,108,790
# 7      8  Monsters University   $268,492,764          4004   $82,429,469
# 8      9      The Incredibles   $261,441,092          3933   $70,467,623
# 9     10       Monsters, Inc.   $255,873,250          3649   $62,577,067
# 10    11          Toy Story 2   $245,852,179          3257      $300,163
# 11    12                 Cars   $244,082,982          3988   $60,119,509
# ...

# %%
disneypixar['category'] = 'pixar'
disneypixar
# Out:
#     Rank              Release Lifetime Gross  Max Theaters       Opening  \
# 0      1        Incredibles 2   $608,581,744          4410  $182,687,905
# 1      2         Finding Dory   $486,295,561          4305  $135,060,273
# 2      3          Toy Story 4   $434,038,008          4575  $120,908,065
# 3      4          Toy Story 3   $415,004,880          4028  $110,307,189
# 4      5           Inside Out   $356,461,711          4158   $90,440,272
# 5      6         Finding Nemo   $339,714,978          3425   $70,251,710
# 6      7                   Up   $293,004,164          3886   $68,108,790
# 7      8  Monsters University   $268,492,764          4004   $82,429,469
# 8      9      The Incredibles   $261,441,092          3933   $70,467,623
# 9     10       Monsters, Inc.   $255,873,250          3649   $62,577,067
# 10    11          Toy Story 2   $245,852,179          3257      $300,163
# 11    12                 Cars   $244,082,982          3988   $60,119,509
# ...

# %%
livemarvelpixar = pd.concat([livemarvel, disneypixar])
livemarvelpixar
# Out:
#    Rank               Release Lifetime Gross Max Theaters       Opening  \
# 0     1         The Lion King   $543,638,043         4802  $191,770,759
# 1     2  Beauty and the Beast   $504,014,165         4210  $174,750,616
# 2     3       The Jungle Book   $364,001,123         4144  $103,261,464
# 3     4               Aladdin   $355,559,216         4476   $91,500,929
# 4     5   Alice in Wonderland   $334,191,110         3739  $116,101,023
# ..  ...                   ...            ...          ...           ...
# 17   18                Cars 2   $191,452,396         4115   $66,135,507
# 18   19          A Bug's Life   $162,798,565         2773      $291,121
# 19   20                Cars 3   $152,901,115         4256   $53,688,680
# 20   21     The Good Dinosaur   $123,087,120         3749   $39,155,217
# 21   22                Onward    $61,555,145         4310   $39,119,861
#
#    Open Th  Release Date                          Distributor  Estimated  \
# ...

# %%
livemarvelpixar=livemarvelpixar.reset_index()

# %%
livemarvelpixar=livemarvelpixar.drop(['index'], axis=1)
livemarvelpixar
# Out:
#    Rank               Release Lifetime Gross Max Theaters       Opening  \
# 0     1         The Lion King   $543,638,043         4802  $191,770,759
# 1     2  Beauty and the Beast   $504,014,165         4210  $174,750,616
# 2     3       The Jungle Book   $364,001,123         4144  $103,261,464
# 3     4               Aladdin   $355,559,216         4476   $91,500,929
# 4     5   Alice in Wonderland   $334,191,110         3739  $116,101,023
# ..  ...                   ...            ...          ...           ...
# 66   18                Cars 2   $191,452,396         4115   $66,135,507
# 67   19          A Bug's Life   $162,798,565         2773      $291,121
# 68   20                Cars 3   $152,901,115         4256   $53,688,680
# 69   21     The Good Dinosaur   $123,087,120         3749   $39,155,217
# 70   22                Onward    $61,555,145         4310   $39,119,861
#
#    Open Th  Release Date                          Distributor  Estimated  \
# ...

# %%
disneyspiderman
# Out:
#     Unnamed: 0  Rank                                 Release Lifetime Gross  \
# 0            0     1                 Spider-Man: No Way Home   $804,793,477
# 1            1     2                              Spider-Man   $403,706,375
# 2            2     3               Spider-Man: Far from Home   $390,532,085
# 3            3     4                            Spider-Man 2   $373,585,825
# 4            4     5                            Spider-Man 3   $336,530,303
# 5            5     6                  Spider-Man: Homecoming   $334,201,140
# 6            6     7                  The Amazing Spider-Man   $262,030,663
# 7            7     8                The Amazing Spider-Man 2   $202,853,933
# 8            8     9       Spider-Man: Into the Spider-Verse   $190,241,310
# 9            9    10  Spider-Man: No Way Home2022 Re-release     $9,321,593
# 10          10    11   Spider-Man/Men in Black IIDouble Bill     $6,632,970
#
#     Max Theaters       Opening  Open Th  Release Date  \
# ...

# %%
disneyspiderman=disneyspiderman.drop(['Unnamed: 0'], axis=1)
disneyspiderman
# Out:
#     Rank                                 Release Lifetime Gross  Max Theaters  \
# 0      1                 Spider-Man: No Way Home   $804,793,477          4336
# 1      2                              Spider-Man   $403,706,375          3876
# 2      3               Spider-Man: Far from Home   $390,532,085          4634
# 3      4                            Spider-Man 2   $373,585,825          4166
# 4      5                            Spider-Man 3   $336,530,303          4324
# 5      6                  Spider-Man: Homecoming   $334,201,140          4348
# 6      7                  The Amazing Spider-Man   $262,030,663          4318
# 7      8                The Amazing Spider-Man 2   $202,853,933          4324
# 8      9       Spider-Man: Into the Spider-Verse   $190,241,310          3813
# 9     10  Spider-Man: No Way Home2022 Re-release     $9,321,593          3935
# 10    11   Spider-Man/Men in Black IIDouble Bill     $6,632,970          2078
#
# ...

# %%
disneyspiderman=disneyspiderman.drop(disneyspiderman.index[9:])
disneyspiderman
# Out:
#    Rank                            Release Lifetime Gross  Max Theaters  \
# 0     1            Spider-Man: No Way Home   $804,793,477          4336
# 1     2                         Spider-Man   $403,706,375          3876
# 2     3          Spider-Man: Far from Home   $390,532,085          4634
# 3     4                       Spider-Man 2   $373,585,825          4166
# 4     5                       Spider-Man 3   $336,530,303          4324
# 5     6             Spider-Man: Homecoming   $334,201,140          4348
# 6     7             The Amazing Spider-Man   $262,030,663          4318
# 7     8           The Amazing Spider-Man 2   $202,853,933          4324
# 8     9  Spider-Man: Into the Spider-Verse   $190,241,310          3813
#
#         Opening  Open Th  Release Date                        Distributor  \
# 0  $260,138,569     4336  Dec 17, 2021  Sony Pictures Entertainment (SPE)
# 1  $114,844,116     3615   May 3, 2002  Sony Pictures Entertainment (SPE)
# ...

# %%
disneyspiderman['category'] = 'spiderman'
disneyspiderman
# Out:
#    Rank                            Release Lifetime Gross  Max Theaters  \
# 0     1            Spider-Man: No Way Home   $804,793,477          4336
# 1     2                         Spider-Man   $403,706,375          3876
# 2     3          Spider-Man: Far from Home   $390,532,085          4634
# 3     4                       Spider-Man 2   $373,585,825          4166
# 4     5                       Spider-Man 3   $336,530,303          4324
# 5     6             Spider-Man: Homecoming   $334,201,140          4348
# 6     7             The Amazing Spider-Man   $262,030,663          4318
# 7     8           The Amazing Spider-Man 2   $202,853,933          4324
# 8     9  Spider-Man: Into the Spider-Verse   $190,241,310          3813
#
#         Opening  Open Th  Release Date                        Distributor  \
# 0  $260,138,569     4336  Dec 17, 2021  Sony Pictures Entertainment (SPE)
# 1  $114,844,116     3615   May 3, 2002  Sony Pictures Entertainment (SPE)
# ...

# %%
lmps = pd.concat([livemarvelpixar, disneyspiderman])
lmps
# Out:
#    Rank                            Release Lifetime Gross Max Theaters  \
# 0     1                      The Lion King   $543,638,043         4802
# 1     2               Beauty and the Beast   $504,014,165         4210
# 2     3                    The Jungle Book   $364,001,123         4144
# 3     4                            Aladdin   $355,559,216         4476
# 4     5                Alice in Wonderland   $334,191,110         3739
# ..  ...                                ...            ...          ...
# 4     5                       Spider-Man 3   $336,530,303         4324
# 5     6             Spider-Man: Homecoming   $334,201,140         4348
# 6     7             The Amazing Spider-Man   $262,030,663         4318
# 7     8           The Amazing Spider-Man 2   $202,853,933         4324
# 8     9  Spider-Man: Into the Spider-Verse   $190,241,310         3813
#
#          Opening Open Th  Release Date                          Distributor  \
# ...

# %%
lmps=lmps.reset_index()

# %%
lmps=lmps.drop(['index'], axis=1)
lmps
# Out:
#    Rank                            Release Lifetime Gross Max Theaters  \
# 0     1                      The Lion King   $543,638,043         4802
# 1     2               Beauty and the Beast   $504,014,165         4210
# 2     3                    The Jungle Book   $364,001,123         4144
# 3     4                            Aladdin   $355,559,216         4476
# 4     5                Alice in Wonderland   $334,191,110         3739
# ..  ...                                ...            ...          ...
# 75    5                       Spider-Man 3   $336,530,303         4324
# 76    6             Spider-Man: Homecoming   $334,201,140         4348
# 77    7             The Amazing Spider-Man   $262,030,663         4318
# 78    8           The Amazing Spider-Man 2   $202,853,933         4324
# 79    9  Spider-Man: Into the Spider-Verse   $190,241,310         3813
#
#          Opening Open Th  Release Date                          Distributor  \
# ...

# %%
disneystarwars
# Out:
#     Unnamed: 0 Rank                                            Release  \
# 0            0    1         Star Wars: Episode VII - The Force Awakens
# 1            1    2            Star Wars: Episode VIII - The Last Jedi
# 2            2    3                       Rogue One: A Star Wars Story
# 3            3    4      Star Wars: Episode IX - The Rise of Skywalker
# 4            4    5          Star Wars: Episode I - The Phantom Menace
# 5            5    6       Star Wars: Episode III - Revenge of the Sith
# 6            6    7                 Star Wars: Episode IV - A New Hope
# 7            7    8       Star Wars: Episode II - Attack of the Clones
# 8            8    9         Star Wars: Episode VI - Return of the Jedi
# 9            9   10                            Solo: A Star Wars Story
# 10          10   11     Star Wars: Episode V - The Empire Strikes Back
# 11          11   12  Star Wars: Episode IV - A New Hope1997 Special...
# ...

# %%
disneystarwars=disneystarwars.drop(['Unnamed: 0'], axis=1)
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 11   12  Star Wars: Episode IV - A New Hope1997 Special...   $138,257,865
# ...

# %%
disneystarwars['Release']
# Out:
# 0            Star Wars: Episode VII - The Force Awakens
# 1               Star Wars: Episode VIII - The Last Jedi
# 2                          Rogue One: A Star Wars Story
# 3         Star Wars: Episode IX - The Rise of Skywalker
# 4             Star Wars: Episode I - The Phantom Menace
# 5          Star Wars: Episode III - Revenge of the Sith
# 6                    Star Wars: Episode IV - A New Hope
# 7          Star Wars: Episode II - Attack of the Clones
# 8            Star Wars: Episode VI - Return of the Jedi
# 9                               Solo: A Star Wars Story
# 10       Star Wars: Episode V - The Empire Strikes Back
# 11    Star Wars: Episode IV - A New Hope1997 Special...
# 12    Star Wars: Episode V - The Empire Strikes Back...
# 13    Star Wars: Episode VI - Return of the Jedi1997...
# 14    Star Wars: Episode I - The Phantom Menace2012 ...
# 15                            Star Wars: The Clone Wars
# 16    Star Wars: Episode IV - A New Hope1982 Re-release
# ...

# %%
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 11   12  Star Wars: Episode IV - A New Hope1997 Special...   $138,257,865
# ...

# %%
disneystarwars=disneystarwars.drop(disneystarwars.index[11])
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 12   13  Star Wars: Episode V - The Empire Strikes Back...    $67,597,694
# ...

# %%
disneystarwars=disneystarwars.drop(disneystarwars.index[12])
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 12   13  Star Wars: Episode V - The Empire Strikes Back...    $67,597,694
# ...

# %%
disneystarwars=disneystarwars.drop(disneystarwars.index[12])
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 12   13  Star Wars: Episode V - The Empire Strikes Back...    $67,597,694
# ...

# %%
disneystarwars=disneystarwars.drop(disneystarwars.index[11])
disneystarwars
# Out:
#    Rank                                            Release Lifetime Gross  \
# 0     1         Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2            Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                       Rogue One: A Star Wars Story   $532,177,324
# 3     4      Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5          Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6       Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7                 Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8       Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9         Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                            Solo: A Star Wars Story   $213,767,512
# 10   11     Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 15   16                          Star Wars: The Clone Wars    $35,161,554
# ...

# %%
disneystarwars=disneystarwars.drop(disneystarwars.index[12:])
disneystarwars
# Out:
#    Rank                                         Release Lifetime Gross  \
# 0     1      Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2         Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                    Rogue One: A Star Wars Story   $532,177,324
# 3     4   Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5       Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6    Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7              Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                         Solo: A Star Wars Story   $213,767,512
# 10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 15   16                       Star Wars: The Clone Wars    $35,161,554
#
# ...

# %%
disneystarwars=disneystarwars.reset_index()
disneystarwars
# Out:
#     index Rank                                         Release Lifetime Gross  \
# 0       0    1      Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1       1    2         Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2       2    3                    Rogue One: A Star Wars Story   $532,177,324
# 3       3    4   Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4       4    5       Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5       5    6    Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6       6    7              Star Wars: Episode IV - A New Hope   $307,263,857
# 7       7    8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8       8    9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9       9   10                         Solo: A Star Wars Story   $213,767,512
# 10     10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# ...

# %%
disneystarwars=disneystarwars.drop(['index'], axis=1)
disneystarwars
# Out:
#    Rank                                         Release Lifetime Gross  \
# 0     1      Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2         Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                    Rogue One: A Star Wars Story   $532,177,324
# 3     4   Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5       Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6    Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7              Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                         Solo: A Star Wars Story   $213,767,512
# 10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 11   16                       Star Wars: The Clone Wars    $35,161,554
#
# ...

# %%
disneystarwars['category'] = 'starwars'
disneystarwars
# Out:
#    Rank                                         Release Lifetime Gross  \
# 0     1      Star Wars: Episode VII - The Force Awakens   $936,662,225
# 1     2         Star Wars: Episode VIII - The Last Jedi   $620,181,382
# 2     3                    Rogue One: A Star Wars Story   $532,177,324
# 3     4   Star Wars: Episode IX - The Rise of Skywalker   $515,202,542
# 4     5       Star Wars: Episode I - The Phantom Menace   $431,088,295
# 5     6    Star Wars: Episode III - Revenge of the Sith   $380,270,577
# 6     7              Star Wars: Episode IV - A New Hope   $307,263,857
# 7     8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                         Solo: A Star Wars Story   $213,767,512
# 10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 11   16                       Star Wars: The Clone Wars    $35,161,554
#
# ...

# %%
lmpss = pd.concat([lmps, disneystarwars])
lmpss
# Out:
#    Rank                                         Release Lifetime Gross  \
# 0     1                                   The Lion King   $543,638,043
# 1     2                            Beauty and the Beast   $504,014,165
# 2     3                                 The Jungle Book   $364,001,123
# 3     4                                         Aladdin   $355,559,216
# 4     5                             Alice in Wonderland   $334,191,110
# ..  ...                                             ...            ...
# 7     8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 8     9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 9    10                         Solo: A Star Wars Story   $213,767,512
# 10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 11   16                       Star Wars: The Clone Wars    $35,161,554
#
#    Max Theaters       Opening Open Th  Release Date  \
# 0          4802  $191,770,759    4725  Jul 19, 2019
# ...

# %%
lmpss=lmpss.reset_index()
lmpss
# Out:
#     index Rank                                         Release Lifetime Gross  \
# 0       0    1                                   The Lion King   $543,638,043
# 1       1    2                            Beauty and the Beast   $504,014,165
# 2       2    3                                 The Jungle Book   $364,001,123
# 3       3    4                                         Aladdin   $355,559,216
# 4       4    5                             Alice in Wonderland   $334,191,110
# ..    ...  ...                                             ...            ...
# 87      7    8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 88      8    9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 89      9   10                         Solo: A Star Wars Story   $213,767,512
# 90     10   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 91     11   16                       Star Wars: The Clone Wars    $35,161,554
#
# ...

# %%
lmpss=lmpss.drop(['index'], axis=1)
lmpss
# Out:
#    Rank                                         Release Lifetime Gross  \
# 0     1                                   The Lion King   $543,638,043
# 1     2                            Beauty and the Beast   $504,014,165
# 2     3                                 The Jungle Book   $364,001,123
# 3     4                                         Aladdin   $355,559,216
# 4     5                             Alice in Wonderland   $334,191,110
# ..  ...                                             ...            ...
# 87    8    Star Wars: Episode II - Attack of the Clones   $302,191,252
# 88    9      Star Wars: Episode VI - Return of the Jedi   $252,583,617
# 89   10                         Solo: A Star Wars Story   $213,767,512
# 90   11  Star Wars: Episode V - The Empire Strikes Back   $209,398,025
# 91   16                       Star Wars: The Clone Wars    $35,161,554
#
#    Max Theaters       Opening Open Th  Release Date  \
# 0          4802  $191,770,759    4725  Jul 19, 2019
# ...

# %% [markdown]
# lmpss=lmpss.drop(['level_0'], axis=1)
# lmpss

# %%
disneywdanimation
# Out:
#     Unnamed: 0  Rank                    Release Lifetime Gross  Max Theaters  \
# 0            0     1                  Frozen II   $477,373,578          4440
# 1            1     2                     Frozen   $400,738,009          3742
# 2            2     3                   Zootopia   $341,268,248          3959
# 3            3     4                      Moana   $248,757,044          3875
# 4            4     5                 Big Hero 6   $222,527,828          3773
# 5            5     6  Ralph Breaks the Internet   $201,091,711          4017
# 6            6     7                    Tangled   $200,821,936          3603
# 7            7     8             Wreck-It Ralph   $189,422,889          3752
# 8            8     9                       Bolt   $114,053,579          3654
# 9            9    10  The Princess and the Frog   $104,400,899          3475
# 10          10    11         Meet the Robinsons    $97,822,171          3435
# ...

# %%
disneywdanimation=disneywdanimation.drop(['Unnamed: 0'], axis=1)
disneywdanimation
# Out:
#     Rank                    Release Lifetime Gross  Max Theaters  \
# 0      1                  Frozen II   $477,373,578          4440
# 1      2                     Frozen   $400,738,009          3742
# 2      3                   Zootopia   $341,268,248          3959
# 3      4                      Moana   $248,757,044          3875
# 4      5                 Big Hero 6   $222,527,828          3773
# 5      6  Ralph Breaks the Internet   $201,091,711          4017
# 6      7                    Tangled   $200,821,936          3603
# 7      8             Wreck-It Ralph   $189,422,889          3752
# 8      9                       Bolt   $114,053,579          3654
# 9     10  The Princess and the Frog   $104,400,899          3475
# 10    11         Meet the Robinsons    $97,822,171          3435
# 11    12                    Encanto    $96,093,622          3980
# 12    13   Raya and the Last Dragon    $54,723,032          2375
# ...

# %%
disneywdanimation=disneywdanimation.drop(disneywdanimation.index[14])
disneywdanimation
# Out:
#     Rank                    Release Lifetime Gross  Max Theaters  \
# 0      1                  Frozen II   $477,373,578          4440
# 1      2                     Frozen   $400,738,009          3742
# 2      3                   Zootopia   $341,268,248          3959
# 3      4                      Moana   $248,757,044          3875
# 4      5                 Big Hero 6   $222,527,828          3773
# 5      6  Ralph Breaks the Internet   $201,091,711          4017
# 6      7                    Tangled   $200,821,936          3603
# 7      8             Wreck-It Ralph   $189,422,889          3752
# 8      9                       Bolt   $114,053,579          3654
# 9     10  The Princess and the Frog   $104,400,899          3475
# 10    11         Meet the Robinsons    $97,822,171          3435
# 11    12                    Encanto    $96,093,622          3980
# 12    13   Raya and the Last Dragon    $54,723,032          2375
# ...

# %%
disneywdanimation['category'] = 'animated'
disneywdanimation
# Out:
#     Rank                    Release Lifetime Gross  Max Theaters  \
# 0      1                  Frozen II   $477,373,578          4440
# 1      2                     Frozen   $400,738,009          3742
# 2      3                   Zootopia   $341,268,248          3959
# 3      4                      Moana   $248,757,044          3875
# 4      5                 Big Hero 6   $222,527,828          3773
# 5      6  Ralph Breaks the Internet   $201,091,711          4017
# 6      7                    Tangled   $200,821,936          3603
# 7      8             Wreck-It Ralph   $189,422,889          3752
# 8      9                       Bolt   $114,053,579          3654
# 9     10  The Princess and the Frog   $104,400,899          3475
# 10    11         Meet the Robinsons    $97,822,171          3435
# 11    12                    Encanto    $96,093,622          3980
# 12    13   Raya and the Last Dragon    $54,723,032          2375
# ...

# %%
lmpssa = pd.concat([lmpss, disneywdanimation])
lmpssa
# Out:
#    Rank                    Release Lifetime Gross Max Theaters       Opening  \
# 0     1              The Lion King   $543,638,043         4802  $191,770,759
# 1     2       Beauty and the Beast   $504,014,165         4210  $174,750,616
# 2     3            The Jungle Book   $364,001,123         4144  $103,261,464
# 3     4                    Aladdin   $355,559,216         4476   $91,500,929
# 4     5        Alice in Wonderland   $334,191,110         3739  $116,101,023
# ..  ...                        ...            ...          ...           ...
# 9    10  The Princess and the Frog   $104,400,899         3475      $786,190
# 10   11         Meet the Robinsons    $97,822,171         3435   $25,123,781
# 11   12                    Encanto    $96,093,622         3980   $27,206,494
# 12   13   Raya and the Last Dragon    $54,723,032         2375    $8,502,498
# 13   14            Winnie the Pooh    $26,692,846         2405    $7,857,076
#
# ...

# %%
lmpssa=lmpssa.reset_index()
lmpssa
# Out:
#      index Rank                    Release Lifetime Gross Max Theaters  \
# 0        0    1              The Lion King   $543,638,043         4802
# 1        1    2       Beauty and the Beast   $504,014,165         4210
# 2        2    3            The Jungle Book   $364,001,123         4144
# 3        3    4                    Aladdin   $355,559,216         4476
# 4        4    5        Alice in Wonderland   $334,191,110         3739
# ..     ...  ...                        ...            ...          ...
# 101      9   10  The Princess and the Frog   $104,400,899         3475
# 102     10   11         Meet the Robinsons    $97,822,171         3435
# 103     11   12                    Encanto    $96,093,622         3980
# 104     12   13   Raya and the Last Dragon    $54,723,032         2375
# 105     13   14            Winnie the Pooh    $26,692,846         2405
#
#           Opening Open Th  Release Date                          Distributor  \
# ...

# %%
lmpssa=lmpssa.drop(['index'], axis=1)
lmpssa
# Out:
#     Rank                    Release Lifetime Gross Max Theaters       Opening  \
# 0      1              The Lion King   $543,638,043         4802  $191,770,759
# 1      2       Beauty and the Beast   $504,014,165         4210  $174,750,616
# 2      3            The Jungle Book   $364,001,123         4144  $103,261,464
# 3      4                    Aladdin   $355,559,216         4476   $91,500,929
# 4      5        Alice in Wonderland   $334,191,110         3739  $116,101,023
# ..   ...                        ...            ...          ...           ...
# 101   10  The Princess and the Frog   $104,400,899         3475      $786,190
# 102   11         Meet the Robinsons    $97,822,171         3435   $25,123,781
# 103   12                    Encanto    $96,093,622         3980   $27,206,494
# 104   13   Raya and the Last Dragon    $54,723,032         2375    $8,502,498
# 105   14            Winnie the Pooh    $26,692,846         2405    $7,857,076
#
# ...

# %%
disneytotal = pd.read_csv('data/disney_movies_total_gross.csv')

# %%
disneytotal
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
disneymovies = pd.read_csv('data/disney_movie_data_final.csv')

# %%
disneymovies
# Out:
#      Unnamed: 0                            title  \
# 0             0          Academy Award Review of
# 1             1  Snow White and the Seven Dwarfs
# 2             2                        Pinocchio
# 3             3                         Fantasia
# 4             4             The Reluctant Dragon
# ..          ...                              ...
# 427         427                             Soul
# 428         428         Raya and the Last Dragon
# 429         429                          Cruella
# 430         430                    Jungle Cruise
# 431         431            The Beatles: Get Back
#
#                                     Production company  \
# 0                              Walt Disney Productions
# 1                              Walt Disney Productions
# 2                              Walt Disney Productions
# 3                              Walt Disney Productions
# 4                              Walt Disney Productions
# ...

# %%
disneymovies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               432 non-null    int64
#  1   title                    432 non-null    object
#  2   Production company       392 non-null    object
#  3   Release date             431 non-null    object
#  4   Running time             422 non-null    object
#  5   Country                  428 non-null    object
#  6   Language                 430 non-null    object
#  7   Running time (int)       422 non-null    float64
#  8   Budget (float)           273 non-null    float64
#  9   Box office (float)       355 non-null    float64
#  10  Release date (datetime)  428 non-null    object
#  11  imdb                     416 non-null    float64
#  12  metascore                283 non-null    float64
#  13  rotten_tomatoes          361 non-null    object
# ...

# %%
disneymovies=disneymovies.drop(['Simplified','Traditional','Adaptation by','Screenplay by','Edited by','Narrated by','Cinematography','Story by'], axis=1)
disneymovies
# Out:
#      Unnamed: 0                            title  \
# 0             0          Academy Award Review of
# 1             1  Snow White and the Seven Dwarfs
# 2             2                        Pinocchio
# 3             3                         Fantasia
# 4             4             The Reluctant Dragon
# ..          ...                              ...
# 427         427                             Soul
# 428         428         Raya and the Last Dragon
# 429         429                          Cruella
# 430         430                    Jungle Cruise
# 431         431            The Beatles: Get Back
#
#                                     Production company  \
# 0                              Walt Disney Productions
# 1                              Walt Disney Productions
# 2                              Walt Disney Productions
# 3                              Walt Disney Productions
# 4                              Walt Disney Productions
# ...

# %%
disneymovies=disneymovies.drop(['Unnamed: 0','Language','Based on'], axis=1)
disneymovies
# Out:
#                                title  \
# 0            Academy Award Review of
# 1    Snow White and the Seven Dwarfs
# 2                          Pinocchio
# 3                           Fantasia
# 4               The Reluctant Dragon
# ..                               ...
# 427                             Soul
# 428         Raya and the Last Dragon
# 429                          Cruella
# 430                    Jungle Cruise
# 431            The Beatles: Get Back
#
#                                     Production company  \
# 0                              Walt Disney Productions
# 1                              Walt Disney Productions
# 2                              Walt Disney Productions
# 3                              Walt Disney Productions
# 4                              Walt Disney Productions
# ..                                                 ...
# 427  ['Walt Disney Pictures', 'Pixar Animation Stud...
# 428  ['Walt Disney Pictures', 'Walt Disney Animatio...
# ...

# %%
disneylist = pd.read_csv('data/fulltitlelist2.csv')
disneylist
# Out:
#      Unnamed: 0                                                  0
# 0             0    \n1.\nSnow White and the Seven Dwarfs\n(1937)\n
# 1             1                          \n2.\nPinocchio\n(1940)\n
# 2             2                           \n3.\nFantasia\n(1940)\n
# 3             3           \n4.\nThe Reluctant Dragon\n(I) (1941)\n
# 4             4                              \n5.\nDumbo\n(1941)\n
# ..          ...                                                ...
# 524         524         \n525.\nBeauty and the Beast\n(I) (2017)\n
# 525         525  \n526.\nPirates of the Caribbean: Dead Men Tel...
# 526         526                           \n527.\nCars 3\n(2017)\n
# 527         527                    \n528.\nIncredibles 2\n(2018)\n
# 528         528                      \n529.\nToy Story 4\n(2019)\n
#
# [529 rows x 2 columns]

# %%
disneytotal.sort_values('release_date')
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
disneymovies_total = pd.merge(disneymovies, disneytotal, 
                               left_on = 'title', right_on = 'movie_title', 
                               how = 'outer')
disneymovies_total
# Out:
#                                title       Production company  \
# 0            Academy Award Review of  Walt Disney Productions
# 1    Snow White and the Seven Dwarfs  Walt Disney Productions
# 2                          Pinocchio  Walt Disney Productions
# 3                           Fantasia  Walt Disney Productions
# 4               The Reluctant Dragon  Walt Disney Productions
# ..                               ...                      ...
# 797                              NaN                      NaN
# 798                              NaN                      NaN
# 799                              NaN                      NaN
# 800                              NaN                      NaN
# 801                              NaN                      NaN
#
#                                           Release date  \
# 0                                     ['May 19, 1937']
# 1    ['December 21, 1937 ( Carthay Circle Theatre ,...
# ...

# %%
disneymovies_total.loc[disneymovies_total['title'] == 'The Lion King']
# Out:
#              title                                 Production company  \
# 212  The Lion King  ['Walt Disney Pictures', 'Walt Disney Feature ...
# 213  The Lion King  ['Walt Disney Pictures', 'Fairview Entertainme...
#
#                                           Release date Running time  \
# 212                 ['June 15, 1994', 'June 24, 1994']   88 minutes
# 213  ['July 9, 2019 ( Hollywood )', 'July 19, 2019 ...  118 minutes
#
#            Country  Running time (int)  Budget (float)  Box office (float)  \
# 212  United States                88.0      45000000.0        9.685000e+08
# 213  United States               118.0     250000000.0        1.657000e+09
#
#     Release date (datetime)  imdb  ...  \
# 212              1994-06-15   8.5  ...
# 213              2019-07-09   8.5  ...
#
#                                  Distributed by            Budget  \
# 212                        Buena Vista Pictures       $45 million
# ...

# %%
disney_mylist = pd.read_csv('data/disney_mylist2.csv')
disney_mylist
# Out:
#      Rank                                     Release        To Date  \
# 0     1.0  Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1     2.0                           Avengers: Endgame  $858,373,000
# 2     3.0                               Black Panther  $700,059,566
# 3     4.0                      Avengers: Infinity War  $678,815,482
# 4     5.0                                The Avengers  $623,357,910
# ..    ...                                         ...            ...
# 627   NaN                                         NaN            NaN
# 628   NaN                                         NaN            NaN
# 629   NaN                                         NaN            NaN
# 630   NaN                                         NaN            NaN
# 631   NaN                                         NaN            NaN
#
#     Release Date Max Theaters Days        Opening Open Th
# 0      18-Dec-15        4,134  167  $247,966,675    4,134
# ...

# %%
disney_mylist.tail(50)
# Out:
#       Rank                                            Release      To Date  \
# 582  632.0                             A Simple Twist of Fate  $3,430,583
# 583  633.0                                        Father Hood  $3,418,141
# 584  634.0                          Squanto: A Warrior's Tale  $3,342,223
# 585  635.0                                My Boyfriend's Back  $3,335,984
# 586  636.0                                   The Fifth Estate  $3,255,008
# 587  637.0                            Blame It on the Bellboy  $3,104,545
# 588  638.0                                      Running Brave  $3,000,000
# 589  639.0                                   Cradle Will Rock  $2,903,404
# 590  640.0                                   Midnight Madness  $2,900,000
# 591  641.0                                            Newsies  $2,819,485
# 592  643.0                                 Jefferson in Paris  $2,473,668
# 593  644.0                                  Shadow Conspiracy  $2,312,463
# ...

# %%
disney_mylist=disney_mylist.drop(disney_mylist.index[624:])
disney_mylist
# Out:
#       Rank                                            Release        To Date  \
# 0      1.0         Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1      2.0                                  Avengers: Endgame  $858,373,000
# 2      3.0                                      Black Panther  $700,059,566
# 3      4.0                             Avengers: Infinity War  $678,815,482
# 4      5.0                                       The Avengers  $623,357,910
# ..     ...                                                ...            ...
# 619  688.0                                           The Boys       $55,513
# 620  690.0          An Alan Smithee Film: Burn Hollywood Burn       $45,779
# 621  691.0                                    The War at Home       $44,722
# 622  692.0  Century of Cinema: A Personal Journey with Mar...       $39,075
# 623  693.0                                    Walt & El Grupo       $20,521
#
# ...

# %%
disney_mylist=disney_mylist.drop(['Rank'], axis=1)
disney_mylist
# Out:
#                                                Release        To Date  \
# 0           Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1                                    Avengers: Endgame  $858,373,000
# 2                                        Black Panther  $700,059,566
# 3                               Avengers: Infinity War  $678,815,482
# 4                                         The Avengers  $623,357,910
# ..                                                 ...            ...
# 619                                           The Boys       $55,513
# 620          An Alan Smithee Film: Burn Hollywood Burn       $45,779
# 621                                    The War at Home       $44,722
# 622  Century of Cinema: A Personal Journey with Mar...       $39,075
# 623                                    Walt & El Grupo       $20,521
#
#     Release Date Max Theaters Days        Opening Open Th
# 0      18-Dec-15        4,134  167  $247,966,675    4,134
# ...

# %%
disney_mylist.loc[disney_mylist['Release'] == 'The Lion King']
# Out:
#           Release        To Date Release Date Max Theaters Days  \
# 7   The Lion King  $543,638,043     19-Jul-19        4,802  139
# 34  The Lion King  $312,855,561     15-Jun-94        2,624    -
#
#           Opening Open Th
# 7   $191,770,759    4,725
# 34    $1,586,753        2

# %%
lmpssa
# Out:
#     Rank                    Release Lifetime Gross Max Theaters       Opening  \
# 0      1              The Lion King   $543,638,043         4802  $191,770,759
# 1      2       Beauty and the Beast   $504,014,165         4210  $174,750,616
# 2      3            The Jungle Book   $364,001,123         4144  $103,261,464
# 3      4                    Aladdin   $355,559,216         4476   $91,500,929
# 4      5        Alice in Wonderland   $334,191,110         3739  $116,101,023
# ..   ...                        ...            ...          ...           ...
# 101   10  The Princess and the Frog   $104,400,899         3475      $786,190
# 102   11         Meet the Robinsons    $97,822,171         3435   $25,123,781
# 103   12                    Encanto    $96,093,622         3980   $27,206,494
# 104   13   Raya and the Last Dragon    $54,723,032         2375    $8,502,498
# 105   14            Winnie the Pooh    $26,692,846         2405    $7,857,076
#
# ...

# %%
disney_mylist_lmpssa = pd.merge(disney_mylist, lmpssa, 
                               left_on = 'Release', right_on = 'Release', 
                               how = 'outer')
disney_mylist_lmpssa
# Out:
#                                             Release        To Date  \
# 0        Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1                                 Avengers: Endgame  $858,373,000
# 2                                     Black Panther  $700,059,566
# 3                            Avengers: Infinity War  $678,815,482
# 4                                      The Avengers  $623,357,910
# ..                                              ...            ...
# 647              Star Wars: Episode IV - A New Hope            NaN
# 648    Star Wars: Episode II - Attack of the Clones            NaN
# 649      Star Wars: Episode VI - Return of the Jedi            NaN
# 650  Star Wars: Episode V - The Empire Strikes Back            NaN
# 651                       Star Wars: The Clone Wars            NaN
#
#     Release Date_x Max Theaters_x Days      Opening_x Open Th_x Rank  \
# 0        18-Dec-15          4,134  167  $247,966,675      4,134    1
# ...

# %%
disney_mylist_lmpssa=disney_mylist_lmpssa.drop(['Estimated'], axis=1)
disney_mylist_lmpssa
# Out:
#                                             Release        To Date  \
# 0        Star Wars: Episode VII - The Force Awakens  $936,662,225
# 1                                 Avengers: Endgame  $858,373,000
# 2                                     Black Panther  $700,059,566
# 3                            Avengers: Infinity War  $678,815,482
# 4                                      The Avengers  $623,357,910
# ..                                              ...            ...
# 647              Star Wars: Episode IV - A New Hope            NaN
# 648    Star Wars: Episode II - Attack of the Clones            NaN
# 649      Star Wars: Episode VI - Return of the Jedi            NaN
# 650  Star Wars: Episode V - The Empire Strikes Back            NaN
# 651                       Star Wars: The Clone Wars            NaN
#
#     Release Date_x Max Theaters_x Days      Opening_x Open Th_x Rank  \
# 0        18-Dec-15          4,134  167  $247,966,675      4,134    1
# ...

# %%
disney_mylist_lmpssa.loc[disney_mylist_lmpssa['category'] == 'starwars']
# Out:
#                                             Release        To Date  \
# 0        Star Wars: Episode VII - The Force Awakens  $936,662,225
# 5           Star Wars: Episode VIII - The Last Jedi  $620,181,382
# 9                      Rogue One: A Star Wars Story  $532,177,324
# 10    Star Wars: Episode IX - The Rise of Skywalker  $515,202,542
# 68                          Solo: A Star Wars Story  $213,767,512
# 645       Star Wars: Episode I - The Phantom Menace            NaN
# 646    Star Wars: Episode III - Revenge of the Sith            NaN
# 647              Star Wars: Episode IV - A New Hope            NaN
# 648    Star Wars: Episode II - Attack of the Clones            NaN
# 649      Star Wars: Episode VI - Return of the Jedi            NaN
# 650  Star Wars: Episode V - The Empire Strikes Back            NaN
# 651                       Star Wars: The Clone Wars            NaN
#
#     Release Date_x Max Theaters_x Days      Opening_x Open Th_x Rank  \
# ...

# %%
disney_mylist_lmpssa.loc[disney_mylist_lmpssa['category'].isnull()]
# Out:
#                                                Release        To Date  \
# 19          Pirates of the Caribbean: Dead Man's Chest  $423,315,812
# 42            Pirates of the Caribbean: At World's End  $309,420,425
# 43   Pirates of the Caribbean: The Curse of the Bla...  $305,413,918
# 44                                  The Little Mermaid  $296,989,468
# 45                                  The Little Mermaid   $84,355,863
# ..                                                 ...            ...
# 622                                           The Boys       $55,513
# 623          An Alan Smithee Film: Burn Hollywood Burn       $45,779
# 624                                    The War at Home       $44,722
# 625  Century of Cinema: A Personal Journey with Mar...       $39,075
# 626                                    Walt & El Grupo       $20,521
#
#     Release Date_x Max Theaters_x Days      Opening_x Open Th_x Rank  \
# ...

# %%
disney_mylist_lmpssa.to_csv()
# Out:
# ',Release,To Date,Release Date_x,Max Theaters_x,Days,Opening_x,Open Th_x,Rank,Lifetime Gross,Max Theaters_y,Opening_y,Open Th_y,Release Date_y,Distributor,category\r\n0,Star Wars: Episode VII - The Force Awakens,"$936,662,225 ",18-Dec-15,"4,134",167,"$247,966,675 ","4,134",1,"$936,662,225",4134,"$247,966,675",4134,"Dec 18, 2015",Walt Disney Studios Motion Pictures,starwars\r\n1,Avengers: Endgame,"$858,373,000 ",26-Apr-19,"4,662",139,"$357,115,007 ","4,662",1,"$858,373,000",4662,"$357,115,007",4662,"Apr 26, 2019",Walt Disney Studios Motion Pictures,marvel\r\n2,Black Panther,"$700,059,566 ",16-Feb-18,"4,084",174,"$202,003,951 ","4,020",3,"$700,059,566",4084,"$202,003,951",4020,"Feb 16, 2018",Walt Disney Studios Motion Pictures,marvel\r\n3,Avengers: Infinity War,"$678,815,482 ",27-Apr-18,"4,474",139,"$257,698,183 ","4,474",4,"$678,815,482",4474,"$257,698,183",4474,"Apr 27, 2018",Walt Disney Studios Motion Pictures,marvel\r\n4,The Avengers,"$623,357,910 ",4-May-12,"4,349",153,"$207,438,7
# ...

# %%
import os  
os.makedirs('data', exist_ok=True)  
disney_mylist_lmpssa.to_csv('data/mylist_lmpssa.csv')
